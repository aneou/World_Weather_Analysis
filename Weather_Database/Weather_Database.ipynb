# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import time

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude coordinates.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coords = list(zip(lats, lngs))

# %%
#create a list of cities nearest to the coordinates
cities = []

for coordinate in coords:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #Add cities not already in cities list
    if city not in cities:
        cities.append(city)
#print the city count
len(cities)
# Out:
# 771

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 60 == 0 and i >= 60):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | mareeba
# Processing Record 6 of Set 1 | gijon
# Processing Record 7 of Set 1 | seoul
# Processing Record 8 of Set 1 | riyadh
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 1 | srednekolymsk
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | baker city
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | karratha
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | hay river
# Processing Record 23 of Set 1 | bilma
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | abapo
# Processing Record 26 of Set 1 | warrnambool
# Processing Record 27 of Set 1 | oistins
# Processing Record 28 of Set 1 | airai
# Processing Record 29 of Set 1 | port-gentil
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | mazara del vallo
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | beira
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | kiunga
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | roma
# Processing Record 42 of Set 1 | goderich
# Processing Record 43 of Set 1 | vao
# Processing Record 44 of Set 1 | lekoni
# Processing Record 45 of Set 1 | el wasta
# City not found. Skipping...
# Processing Record 46 of Set 1 | nizhnevartovsk
# Processing Record 47 of Set 1 | turinsk
# Processing Record 48 of Set 1 | mandalgovi
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | seryshevo
# Processing Record 51 of Set 1 | puerto rico
# Processing Record 52 of Set 1 | te anau
# Processing Record 53 of Set 1 | kapaa
# Processing Record 54 of Set 1 | gallup
# Processing Record 55 of Set 1 | hailun
# Processing Record 56 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 57 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 58 of Set 1 | kodiak
# Processing Record 59 of Set 1 | hamilton
# Processing Record 60 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | tura
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | aksu
# Processing Record 9 of Set 2 | talara
# Processing Record 10 of Set 2 | kota kinabalu
# Processing Record 11 of Set 2 | rocha
# Processing Record 12 of Set 2 | barentu
# Processing Record 13 of Set 2 | moussoro
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | halifax
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | carballo
# Processing Record 18 of Set 2 | chizhou
# Processing Record 19 of Set 2 | fonte boa
# Processing Record 20 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 2 | upernavik
# Processing Record 22 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 2 | rabaul
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | umm kaddadah
# Processing Record 27 of Set 2 | port hedland
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | port blair
# Processing Record 30 of Set 2 | skive
# Processing Record 31 of Set 2 | garmsar
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 2 | angoram
# Processing Record 36 of Set 2 | bardiyah
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 2 | fort nelson
# Processing Record 43 of Set 2 | taltal
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | chlorakas
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | barranca de upia
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | vila franca do campo
# Processing Record 50 of Set 2 | waingapu
# Processing Record 51 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 52 of Set 2 | pangnirtung
# Processing Record 53 of Set 2 | yulara
# Processing Record 54 of Set 2 | hobart
# Processing Record 55 of Set 2 | kavieng
# Processing Record 56 of Set 2 | cayenne
# Processing Record 57 of Set 2 | benguela
# Processing Record 58 of Set 2 | inhambane
# Processing Record 59 of Set 2 | kendari
# Processing Record 60 of Set 2 | nylstroom
# City not found. Skipping...
# Processing Record 1 of Set 3 | ambositra
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | holguin
# Processing Record 5 of Set 3 | zhezkazgan
# Processing Record 6 of Set 3 | gushikawa
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | lac du bonnet
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | umm lajj
# Processing Record 12 of Set 3 | boden
# Processing Record 13 of Set 3 | san andres
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | labrea
# Processing Record 17 of Set 3 | thatta
# Processing Record 18 of Set 3 | honningsvag
# Processing Record 19 of Set 3 | mehamn
# Processing Record 20 of Set 3 | parabel
# Processing Record 21 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | atar
# Processing Record 25 of Set 3 | fairbanks
# Processing Record 26 of Set 3 | lianran
# Processing Record 27 of Set 3 | maniitsoq
# Processing Record 28 of Set 3 | tiznit
# Processing Record 29 of Set 3 | jinka
# Processing Record 30 of Set 3 | kruisfontein
# Processing Record 31 of Set 3 | akureyri
# Processing Record 32 of Set 3 | qeshm
# Processing Record 33 of Set 3 | tsurugi
# Processing Record 34 of Set 3 | bambous virieux
# Processing Record 35 of Set 3 | punta arenas
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | laguna
# Processing Record 38 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 3 | souillac
# Processing Record 40 of Set 3 | asfi
# Processing Record 41 of Set 3 | shingu
# Processing Record 42 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 3 | kaitangata
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | gerash
# Processing Record 48 of Set 3 | samarai
# Processing Record 49 of Set 3 | mercedes
# Processing Record 50 of Set 3 | podgornoye
# Processing Record 51 of Set 3 | hervey bay
# Processing Record 52 of Set 3 | sioux lookout
# Processing Record 53 of Set 3 | sechura
# Processing Record 54 of Set 3 | aksum
# Processing Record 55 of Set 3 | sinjar
# Processing Record 56 of Set 3 | cape town
# Processing Record 57 of Set 3 | tilichiki
# Processing Record 58 of Set 3 | chuy
# Processing Record 59 of Set 3 | ust-tsilma
# Processing Record 60 of Set 3 | santo antonio do monte
# Processing Record 1 of Set 4 | amapa
# Processing Record 2 of Set 4 | lasa
# Processing Record 3 of Set 4 | mardin
# Processing Record 4 of Set 4 | mount isa
# Processing Record 5 of Set 4 | kanniyakumari
# Processing Record 6 of Set 4 | novobirilyussy
# Processing Record 7 of Set 4 | hokitika
# Processing Record 8 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 4 | marawi
# Processing Record 11 of Set 4 | cockburn town
# Processing Record 12 of Set 4 | wangaratta
# Processing Record 13 of Set 4 | buin
# Processing Record 14 of Set 4 | malakal
# Processing Record 15 of Set 4 | kabinda
# Processing Record 16 of Set 4 | kizema
# Processing Record 17 of Set 4 | nambucca heads
# Processing Record 18 of Set 4 | mombetsu
# Processing Record 19 of Set 4 | aitape
# Processing Record 20 of Set 4 | teguise
# Processing Record 21 of Set 4 | ambilobe
# Processing Record 22 of Set 4 | najran
# Processing Record 23 of Set 4 | miraflores
# Processing Record 24 of Set 4 | georgetown
# Processing Record 25 of Set 4 | zhangjiakou
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | sinop
# Processing Record 28 of Set 4 | sur
# Processing Record 29 of Set 4 | oyama
# Processing Record 30 of Set 4 | vuyyuru
# Processing Record 31 of Set 4 | rorvik
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | kalmunai
# Processing Record 34 of Set 4 | avarua
# Processing Record 35 of Set 4 | bogo
# Processing Record 36 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 4 | acapulco
# Processing Record 38 of Set 4 | chimore
# Processing Record 39 of Set 4 | kieta
# Processing Record 40 of Set 4 | vila
# Processing Record 41 of Set 4 | grand gaube
# Processing Record 42 of Set 4 | caravelas
# Processing Record 43 of Set 4 | lagoa
# Processing Record 44 of Set 4 | sistranda
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | san quintin
# Processing Record 49 of Set 4 | arlit
# Processing Record 50 of Set 4 | touros
# Processing Record 51 of Set 4 | minot
# Processing Record 52 of Set 4 | poplar bluff
# Processing Record 53 of Set 4 | abbeville
# Processing Record 54 of Set 4 | mar del plata
# Processing Record 55 of Set 4 | gibsons
# Processing Record 56 of Set 4 | stonewall
# Processing Record 57 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 58 of Set 4 | kavaratti
# Processing Record 59 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 60 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | valsad
# Processing Record 2 of Set 5 | nanning
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | vuktyl
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | krutinka
# Processing Record 7 of Set 5 | baruun-urt
# Processing Record 8 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 5 | deputatskiy
# Processing Record 10 of Set 5 | aklavik
# Processing Record 11 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 5 | bairiki
# Processing Record 13 of Set 5 | miracema do tocantins
# Processing Record 14 of Set 5 | namanga
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | aloleng
# Processing Record 17 of Set 5 | zyryanka
# Processing Record 18 of Set 5 | vardo
# Processing Record 19 of Set 5 | asau
# Processing Record 20 of Set 5 | coihaique
# Processing Record 21 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 22 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | broome
# Processing Record 24 of Set 5 | andijon
# Processing Record 25 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 5 | kenai
# Processing Record 27 of Set 5 | coahuayana
# Processing Record 28 of Set 5 | khuzhir
# Processing Record 29 of Set 5 | camalu
# Processing Record 30 of Set 5 | fukue
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | kyabe
# Processing Record 33 of Set 5 | guerrero negro
# Processing Record 34 of Set 5 | whitehorse
# Processing Record 35 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 36 of Set 5 | jiayuguan
# Processing Record 37 of Set 5 | dehui
# Processing Record 38 of Set 5 | palmeira das missoes
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | east london
# Processing Record 41 of Set 5 | humberto de campos
# Processing Record 42 of Set 5 | phun phin
# City not found. Skipping...
# Processing Record 43 of Set 5 | kavali
# Processing Record 44 of Set 5 | iracoubo
# Processing Record 45 of Set 5 | terme
# Processing Record 46 of Set 5 | santarem
# Processing Record 47 of Set 5 | beringovskiy
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | baijiantan
# Processing Record 50 of Set 5 | college
# Processing Record 51 of Set 5 | sycow
# Processing Record 52 of Set 5 | son la
# Processing Record 53 of Set 5 | san patricio
# Processing Record 54 of Set 5 | mandeville
# Processing Record 55 of Set 5 | isla mujeres
# Processing Record 56 of Set 5 | aguas belas
# Processing Record 57 of Set 5 | shahpur
# Processing Record 58 of Set 5 | ganzhou
# Processing Record 59 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 60 of Set 5 | kincardine
# Processing Record 1 of Set 6 | haukipudas
# Processing Record 2 of Set 6 | hovd
# Processing Record 3 of Set 6 | camana
# Processing Record 4 of Set 6 | hambantota
# Processing Record 5 of Set 6 | barabash
# Processing Record 6 of Set 6 | chifeng
# Processing Record 7 of Set 6 | alzamay
# Processing Record 8 of Set 6 | carnarvon
# Processing Record 9 of Set 6 | cabedelo
# Processing Record 10 of Set 6 | bud
# Processing Record 11 of Set 6 | tres lagoas
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | utete
# Processing Record 14 of Set 6 | jos
# Processing Record 15 of Set 6 | kalawit
# Processing Record 16 of Set 6 | santa rosa del sur
# Processing Record 17 of Set 6 | araouane
# Processing Record 18 of Set 6 | mnogovershinnyy
# Processing Record 19 of Set 6 | yar-sale
# Processing Record 20 of Set 6 | la ronge
# Processing Record 21 of Set 6 | san cristobal
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | morro bay
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | komsomolskiy
# Processing Record 26 of Set 6 | katsuura
# Processing Record 27 of Set 6 | pochutla
# Processing Record 28 of Set 6 | lewisporte
# Processing Record 29 of Set 6 | chimoio
# Processing Record 30 of Set 6 | araioses
# Processing Record 31 of Set 6 | matamoros
# Processing Record 32 of Set 6 | port lincoln
# Processing Record 33 of Set 6 | sabang
# Processing Record 34 of Set 6 | alofi
# Processing Record 35 of Set 6 | berlevag
# Processing Record 36 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 6 | grand-bourg
# Processing Record 38 of Set 6 | kourou
# Processing Record 39 of Set 6 | faanui
# Processing Record 40 of Set 6 | iskateley
# Processing Record 41 of Set 6 | takapau
# Processing Record 42 of Set 6 | benoy
# Processing Record 43 of Set 6 | ribeira grande
# Processing Record 44 of Set 6 | atbasar
# Processing Record 45 of Set 6 | solenzo
# Processing Record 46 of Set 6 | bayanday
# Processing Record 47 of Set 6 | opuwo
# Processing Record 48 of Set 6 | cascais
# Processing Record 49 of Set 6 | arandas
# Processing Record 50 of Set 6 | provideniya
# Processing Record 51 of Set 6 | antofagasta
# Processing Record 52 of Set 6 | codrington
# Processing Record 53 of Set 6 | tornio
# Processing Record 54 of Set 6 | mackay
# Processing Record 55 of Set 6 | junin
# Processing Record 56 of Set 6 | kutum
# Processing Record 57 of Set 6 | mount gambier
# Processing Record 58 of Set 6 | fort saint james
# Processing Record 59 of Set 6 | udachnyy
# Processing Record 60 of Set 6 | vitoria
# Processing Record 1 of Set 7 | ingham
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | kristiansund
# Processing Record 4 of Set 7 | zhigansk
# Processing Record 5 of Set 7 | bom jardim
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | praya
# Processing Record 8 of Set 7 | belomorsk
# Processing Record 9 of Set 7 | gebre guracha
# Processing Record 10 of Set 7 | suntar
# Processing Record 11 of Set 7 | olafsvik
# Processing Record 12 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 7 | iquitos
# Processing Record 14 of Set 7 | kahului
# Processing Record 15 of Set 7 | katoro
# Processing Record 16 of Set 7 | comodoro rivadavia
# Processing Record 17 of Set 7 | unye
# City not found. Skipping...
# Processing Record 18 of Set 7 | viedma
# Processing Record 19 of Set 7 | goalpara
# Processing Record 20 of Set 7 | ilebo
# Processing Record 21 of Set 7 | murud
# Processing Record 22 of Set 7 | visnes
# Processing Record 23 of Set 7 | sobolevo
# Processing Record 24 of Set 7 | puerto escondido
# Processing Record 25 of Set 7 | patiya
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | pingliang
# Processing Record 28 of Set 7 | khatanga
# Processing Record 29 of Set 7 | inyonga
# Processing Record 30 of Set 7 | mbini
# Processing Record 31 of Set 7 | jacareacanga
# Processing Record 32 of Set 7 | buzuluk
# Processing Record 33 of Set 7 | ketchikan
# Processing Record 34 of Set 7 | roald
# Processing Record 35 of Set 7 | yumen
# Processing Record 36 of Set 7 | adrar
# Processing Record 37 of Set 7 | ust-kuyga
# Processing Record 38 of Set 7 | eyl
# Processing Record 39 of Set 7 | thinadhoo
# Processing Record 40 of Set 7 | natchez
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | apricena
# Processing Record 43 of Set 7 | sterling
# Processing Record 44 of Set 7 | kaeo
# Processing Record 45 of Set 7 | naberera
# Processing Record 46 of Set 7 | tommot
# Processing Record 47 of Set 7 | cerkezkoy
# Processing Record 48 of Set 7 | bam
# Processing Record 49 of Set 7 | thomasville
# Processing Record 50 of Set 7 | basco
# Processing Record 51 of Set 7 | choszczno
# Processing Record 52 of Set 7 | santiago del estero
# Processing Record 53 of Set 7 | kungurtug
# Processing Record 54 of Set 7 | tessalit
# Processing Record 55 of Set 7 | nianzishan
# Processing Record 56 of Set 7 | nanortalik
# Processing Record 57 of Set 7 | nome
# Processing Record 58 of Set 7 | verkhnyaya inta
# Processing Record 59 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 60 of Set 7 | langfang
# Processing Record 1 of Set 8 | ostrovnoy
# Processing Record 2 of Set 8 | rudnya
# Processing Record 3 of Set 8 | fernandopolis
# Processing Record 4 of Set 8 | sharjah
# Processing Record 5 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 8 | akdepe
# Processing Record 7 of Set 8 | necochea
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | waw
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | sedan
# Processing Record 12 of Set 8 | mitsamiouli
# Processing Record 13 of Set 8 | shieli
# Processing Record 14 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 8 | wad rawah
# Processing Record 16 of Set 8 | guilin
# Processing Record 17 of Set 8 | sitka
# Processing Record 18 of Set 8 | cap malheureux
# Processing Record 19 of Set 8 | port macquarie
# Processing Record 20 of Set 8 | vaitape
# Processing Record 21 of Set 8 | kristiinankaupunki
# Processing Record 22 of Set 8 | xingyi
# Processing Record 23 of Set 8 | kota belud
# Processing Record 24 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 25 of Set 8 | jaciara
# Processing Record 26 of Set 8 | fomboni
# Processing Record 27 of Set 8 | salo
# Processing Record 28 of Set 8 | ayan
# Processing Record 29 of Set 8 | albion
# Processing Record 30 of Set 8 | mezen
# Processing Record 31 of Set 8 | alakurtti
# Processing Record 32 of Set 8 | duvan
# Processing Record 33 of Set 8 | lahaina
# Processing Record 34 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 8 | fallon
# Processing Record 36 of Set 8 | sibolga
# Processing Record 37 of Set 8 | severo-kurilsk
# Processing Record 38 of Set 8 | namibe
# Processing Record 39 of Set 8 | tual
# Processing Record 40 of Set 8 | pandhana
# Processing Record 41 of Set 8 | nadym
# Processing Record 42 of Set 8 | beloha
# Processing Record 43 of Set 8 | atasu
# Processing Record 44 of Set 8 | irricana
# Processing Record 45 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 8 | hulyaypole
# Processing Record 47 of Set 8 | flin flon
# Processing Record 48 of Set 8 | iqaluit
# Processing Record 49 of Set 8 | bubaque
# Processing Record 50 of Set 8 | naryan-mar
# Processing Record 51 of Set 8 | skibbereen
# Processing Record 52 of Set 8 | ilulissat
# Processing Record 53 of Set 8 | kaduqli
# Processing Record 54 of Set 8 | tocopilla
# Processing Record 55 of Set 8 | aljezur
# Processing Record 56 of Set 8 | bambanglipuro
# Processing Record 57 of Set 8 | tuy hoa
# Processing Record 58 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 59 of Set 8 | luorong
# Processing Record 60 of Set 8 | maningrida
# Processing Record 1 of Set 9 | awbari
# Processing Record 2 of Set 9 | raudeberg
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | tazovskiy
# Processing Record 5 of Set 9 | skelleftea
# Processing Record 6 of Set 9 | toora-khem
# Processing Record 7 of Set 9 | broken hill
# Processing Record 8 of Set 9 | ucluelet
# Processing Record 9 of Set 9 | stromness
# Processing Record 10 of Set 9 | manggar
# Processing Record 11 of Set 9 | ripoll
# Processing Record 12 of Set 9 | bandarbeyla
# Processing Record 13 of Set 9 | ellisras
# Processing Record 14 of Set 9 | almeirim
# Processing Record 15 of Set 9 | kurilsk
# Processing Record 16 of Set 9 | khani
# Processing Record 17 of Set 9 | beni suef
# Processing Record 18 of Set 9 | axim
# Processing Record 19 of Set 9 | matay
# Processing Record 20 of Set 9 | angren
# Processing Record 21 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | avera
# Processing Record 23 of Set 9 | lithakia
# Processing Record 24 of Set 9 | batemans bay
# Processing Record 25 of Set 9 | davila
# Processing Record 26 of Set 9 | marystown
# Processing Record 27 of Set 9 | santa isabel
# Processing Record 28 of Set 9 | maridi
# Processing Record 29 of Set 9 | burnie
# Processing Record 30 of Set 9 | maues
# Processing Record 31 of Set 9 | nicoya
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | jijiga
# Processing Record 34 of Set 9 | harper
# Processing Record 35 of Set 9 | pecos
# Processing Record 36 of Set 9 | korla
# Processing Record 37 of Set 9 | mana
# Processing Record 38 of Set 9 | balsas
# Processing Record 39 of Set 9 | wanning
# Processing Record 40 of Set 9 | cruzeiro do sul
# Processing Record 41 of Set 9 | arrecife
# Processing Record 42 of Set 9 | bilibino
# Processing Record 43 of Set 9 | khash
# Processing Record 44 of Set 9 | yaan
# Processing Record 45 of Set 9 | azuaga
# Processing Record 46 of Set 9 | phan thiet
# Processing Record 47 of Set 9 | ballina
# Processing Record 48 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 9 | oranjemund
# Processing Record 50 of Set 9 | tabas
# Processing Record 51 of Set 9 | san jose
# Processing Record 52 of Set 9 | karasburg
# Processing Record 53 of Set 9 | tarko-sale
# Processing Record 54 of Set 9 | ziniare
# Processing Record 55 of Set 9 | abu zabad
# Processing Record 56 of Set 9 | tamandare
# Processing Record 57 of Set 9 | villa carlos paz
# Processing Record 58 of Set 9 | monchegorsk
# Processing Record 59 of Set 9 | talnakh
# Processing Record 60 of Set 9 | krasnaya gora
# Processing Record 1 of Set 10 | newport
# Processing Record 2 of Set 10 | khlevnoye
# Processing Record 3 of Set 10 | port said
# Processing Record 4 of Set 10 | pedernales
# Processing Record 5 of Set 10 | yola
# Processing Record 6 of Set 10 | ahipara
# Processing Record 7 of Set 10 | shakiso
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | yithion
# City not found. Skipping...
# Processing Record 10 of Set 10 | skjervoy
# Processing Record 11 of Set 10 | asyut
# Processing Record 12 of Set 10 | kysyl-syr
# Processing Record 13 of Set 10 | slave lake
# Processing Record 14 of Set 10 | okha
# Processing Record 15 of Set 10 | hajnowka
# Processing Record 16 of Set 10 | kawalu
# Processing Record 17 of Set 10 | palmer
# Processing Record 18 of Set 10 | klyuchi
# Processing Record 19 of Set 10 | kargasok
# Processing Record 20 of Set 10 | la palma
# Processing Record 21 of Set 10 | vrangel
# Processing Record 22 of Set 10 | grao mogol
# Processing Record 23 of Set 10 | wakkanai
# Processing Record 24 of Set 10 | half moon bay
# Processing Record 25 of Set 10 | derac
# Processing Record 26 of Set 10 | gambo
# Processing Record 27 of Set 10 | nakhodka
# Processing Record 28 of Set 10 | auki
# Processing Record 29 of Set 10 | almaznyy
# Processing Record 30 of Set 10 | rafsanjan
# Processing Record 31 of Set 10 | gardez
# Processing Record 32 of Set 10 | tallahassee
# Processing Record 33 of Set 10 | pathein
# Processing Record 34 of Set 10 | pachino
# Processing Record 35 of Set 10 | den helder
# Processing Record 36 of Set 10 | chabahar
# Processing Record 37 of Set 10 | aksarka
# Processing Record 38 of Set 10 | urengoy
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | les herbiers
# Processing Record 41 of Set 10 | lukulu
# Processing Record 42 of Set 10 | palauig
# Processing Record 43 of Set 10 | mwingi
# Processing Record 44 of Set 10 | paita
# Processing Record 45 of Set 10 | belaya gora
# Processing Record 46 of Set 10 | prince rupert
# Processing Record 47 of Set 10 | lowestoft
# Processing Record 48 of Set 10 | havoysund
# Processing Record 49 of Set 10 | carbonia
# Processing Record 50 of Set 10 | volksrust
# Processing Record 51 of Set 10 | longyan
# Processing Record 52 of Set 10 | dongsheng
# Processing Record 53 of Set 10 | lorengau
# Processing Record 54 of Set 10 | poum
# Processing Record 55 of Set 10 | boulder
# Processing Record 56 of Set 10 | svetlogorsk
# Processing Record 57 of Set 10 | keti bandar
# Processing Record 58 of Set 10 | high level
# Processing Record 59 of Set 10 | hobyo
# Processing Record 60 of Set 10 | kaele
# Processing Record 1 of Set 11 | watsa
# Processing Record 2 of Set 11 | bemidji
# Processing Record 3 of Set 11 | innisfail
# Processing Record 4 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 11 | padang
# Processing Record 6 of Set 11 | shenzhen
# Processing Record 7 of Set 11 | elmira
# Processing Record 8 of Set 11 | rio gallegos
# Processing Record 9 of Set 11 | terrak
# Processing Record 10 of Set 11 | marsa matruh
# Processing Record 11 of Set 11 | ugra
# Processing Record 12 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 11 | ofaqim
# Processing Record 14 of Set 11 | cepelare
# Processing Record 15 of Set 11 | springfield
# Processing Record 16 of Set 11 | popondetta
# Processing Record 17 of Set 11 | buraydah
# Processing Record 18 of Set 11 | jining
# Processing Record 19 of Set 11 | susanville
# Processing Record 20 of Set 11 | temirtau
# Processing Record 21 of Set 11 | camacha
# Processing Record 22 of Set 11 | antigonish
# Processing Record 23 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 11 | qom
# Processing Record 25 of Set 11 | shubarshi
# Processing Record 26 of Set 11 | kovdor
# Processing Record 27 of Set 11 | itarema
# Processing Record 28 of Set 11 | guozhen
# Processing Record 29 of Set 11 | ulladulla
# Processing Record 30 of Set 11 | bharatpur
# Processing Record 31 of Set 11 | rabo de peixe
# Processing Record 32 of Set 11 | dongzhen
# Processing Record 33 of Set 11 | leningradskiy
# Processing Record 34 of Set 11 | longkou
# Processing Record 35 of Set 11 | sile
# Processing Record 36 of Set 11 | kosgi
# City not found. Skipping...
# Processing Record 37 of Set 11 | farah
# Processing Record 38 of Set 11 | katsina
# Processing Record 39 of Set 11 | la rioja
# Processing Record 40 of Set 11 | grajau
# Processing Record 41 of Set 11 | aurad
# Processing Record 42 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 11 | navapur
# City not found. Skipping...
# Processing Record 44 of Set 11 | salinopolis
# Processing Record 45 of Set 11 | amahai
# Processing Record 46 of Set 11 | aden
# Processing Record 47 of Set 11 | shimoda
# Processing Record 48 of Set 11 | karoi
# Processing Record 49 of Set 11 | chara
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 51 of Set 11 | goundam
# Processing Record 52 of Set 11 | cervo
# Processing Record 53 of Set 11 | ilorin
# Processing Record 54 of Set 11 | zeya
# Processing Record 55 of Set 11 | constitucion
# Processing Record 56 of Set 11 | senica
# Processing Record 57 of Set 11 | muroto
# Processing Record 58 of Set 11 | ornskoldsvik
# Processing Record 59 of Set 11 | tevaitoa
# Processing Record 60 of Set 11 | osa
# Processing Record 1 of Set 12 | ponta delgada
# Processing Record 2 of Set 12 | metro
# Processing Record 3 of Set 12 | kirakira
# Processing Record 4 of Set 12 | peniche
# Processing Record 5 of Set 12 | canberra
# Processing Record 6 of Set 12 | huarmey
# Processing Record 7 of Set 12 | peachtree city
# Processing Record 8 of Set 12 | olavarria
# Processing Record 9 of Set 12 | lamu
# Processing Record 10 of Set 12 | dandong
# Processing Record 11 of Set 12 | santa fe
# Processing Record 12 of Set 12 | oshnaviyeh
# Processing Record 13 of Set 12 | teguldet
# Processing Record 14 of Set 12 | bontang
# Processing Record 15 of Set 12 | awjilah
# Processing Record 16 of Set 12 | alice springs
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | esperance
# Processing Record 19 of Set 12 | sosnovskiy
# City not found. Skipping...
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | pacific grove
# Processing Record 22 of Set 12 | along
# Processing Record 23 of Set 12 | plouzane
# Processing Record 24 of Set 12 | rawson
# Processing Record 25 of Set 12 | okakarara
# Processing Record 26 of Set 12 | christchurch
# Processing Record 27 of Set 12 | carevo
# City not found. Skipping...
# Processing Record 28 of Set 12 | urucui
# Processing Record 29 of Set 12 | el copey
# Processing Record 30 of Set 12 | mushie
# Processing Record 31 of Set 12 | ouadda
# Processing Record 32 of Set 12 | shenkursk
# Processing Record 33 of Set 12 | quelimane
# Processing Record 34 of Set 12 | sande
# Processing Record 35 of Set 12 | illapel
# Processing Record 36 of Set 12 | tabou
# Processing Record 37 of Set 12 | ust-kulom
# Processing Record 38 of Set 12 | bandar-e lengeh
# Processing Record 39 of Set 12 | matata
# Processing Record 40 of Set 12 | egvekinot
# Processing Record 41 of Set 12 | barra patuca
# Processing Record 42 of Set 12 | sri aman
# Processing Record 43 of Set 12 | pilar
# Processing Record 44 of Set 12 | jejuri
# Processing Record 45 of Set 12 | sao joao da barra
# Processing Record 46 of Set 12 | ribas do rio pardo
# Processing Record 47 of Set 12 | los llanos de aridane
# Processing Record 48 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 49 of Set 12 | ossora
# Processing Record 50 of Set 12 | sangar
# Processing Record 51 of Set 12 | mogadishu
# Processing Record 52 of Set 12 | diffa
# Processing Record 53 of Set 12 | maceio
# Processing Record 54 of Set 12 | bogorodskoye
# Processing Record 55 of Set 12 | mongoumba
# Processing Record 56 of Set 12 | nemuro
# Processing Record 57 of Set 12 | tolmachevo
# Processing Record 58 of Set 12 | eureka
# Processing Record 59 of Set 12 | baishishan
# Processing Record 60 of Set 12 | kamenka
# Processing Record 1 of Set 13 | lavrentiya
# Processing Record 2 of Set 13 | andenes
# Processing Record 3 of Set 13 | martapura
# Processing Record 4 of Set 13 | smithers
# Processing Record 5 of Set 13 | katherine
# Processing Record 6 of Set 13 | casper
# Processing Record 7 of Set 13 | jogindarnagar
# Processing Record 8 of Set 13 | rumonge
# Processing Record 9 of Set 13 | daokou
# Processing Record 10 of Set 13 | tigil
# Processing Record 11 of Set 13 | quatre cocos
# Processing Record 12 of Set 13 | mackenzie
# Processing Record 13 of Set 13 | ko samui
# Processing Record 14 of Set 13 | gebze
# Processing Record 15 of Set 13 | north bend
# Processing Record 16 of Set 13 | san bartolome de tirajana
# Processing Record 17 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 13 | cacu
# Processing Record 20 of Set 13 | odweyne
# Processing Record 21 of Set 13 | nabire
# Processing Record 22 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 13 | lempaala
# Processing Record 24 of Set 13 | margate
# Processing Record 25 of Set 13 | charters towers
# Processing Record 26 of Set 13 | santa elena
# Processing Record 27 of Set 13 | gimli
# Processing Record 28 of Set 13 | yarmouth
# Processing Record 29 of Set 13 | conceicao do araguaia
# Processing Record 30 of Set 13 | arco
# Processing Record 31 of Set 13 | sandviken
# Processing Record 32 of Set 13 | chegdomyn
# Processing Record 33 of Set 13 | alcudia
# Processing Record 34 of Set 13 | san antonio
# Processing Record 35 of Set 13 | poso
# Processing Record 36 of Set 13 | sidi ali
# Processing Record 37 of Set 13 | benidorm
# Processing Record 38 of Set 13 | kirkwall
# Processing Record 39 of Set 13 | barabai
# Processing Record 40 of Set 13 | port hardy
# Processing Record 41 of Set 13 | talas
# Processing Record 42 of Set 13 | san matias
# Processing Record 43 of Set 13 | haines junction
# Processing Record 44 of Set 13 | sorong
# Processing Record 45 of Set 13 | abu samrah
# Processing Record 46 of Set 13 | mulchen
# Processing Record 47 of Set 13 | chingola
# Processing Record 48 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 49 of Set 13 | xiaoweizhai
# Processing Record 50 of Set 13 | hayden
# Processing Record 51 of Set 13 | bodden town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Geraldton      AU -28.7667  114.6000     93.61        31          40
# 1      Thompson      CA  55.7435  -97.8558     -0.24        85         100
# 2       Rikitea      PF -23.1203 -134.9692     78.37        71          75
# 3  Puerto Ayora      EC  -0.7393  -90.3518     76.55        94          51
# 4       Mareeba      AU -17.0000  145.4333     79.52        83          97
# 5         Gijon      ES  43.5357   -5.6615     60.26        71         100
# 6         Seoul      KR  37.5683  126.9778     26.11        30          40
# 7        Riyadh      SA  24.6877   46.7219     71.74        14           0
# 8  Saint George      US  37.1041 -113.5841     51.64        43           0
# 9      Saldanha      ZA -33.0117   17.9442     75.25        83           2
#
#    Wind Speed Current Description
# 0       25.32    scattered clouds
# 1        3.44     overcast clouds
# 2       12.50       broken clouds
# 3        4.00       broken clouds
# 4        5.66     overcast clouds
# 5        7.00     overcast clouds
# 6       17.27    scattered clouds
# 7        2.30           clear sky
# 8        8.05           clear sky
# 9       19.95           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
